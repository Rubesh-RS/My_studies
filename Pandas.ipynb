# %%
import pandas as pd

# %%
df = pd.read_csv("data\Sales.csv")

# %%
print(df)

# %%
required = ["Sales Person","Quantity"]

# %%
df[required].head(6)

# %%
df[(df["Country"]=="India") & (df["Total"] > 100000)]

# %%
temp_list = [i*i for i in range(20)]

# %%
df["temp_dta"] = temp_list

# %%
df

# %%
new_col = pd.DataFrame([["Singapore", "North", "Rubesh", "7/30/2014 0:00:00", "54334500", "85", "361"]], columns = df.columns.values)

# %%
new_col

# %%
df = pd.concat([df,new_col],ignore_index=True)

# %%
df.to_string()

# %%
df

# %%
df["Quantity"]=df["Quantity"].astype(int)

# %%
df[(df["Country"]== "India") & (df["Quantity"]>200)]

# %%
df
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity  \
# 0       India  North         John   3/17/2018 0:00:00    100000       567
# 1          US  North         Bill   1/21/2010 0:00:00    120000      3000
# 2          UK  North       Thomas   1/25/2015 0:00:00    140000       345
# 3   Australia   East         John   6/29/2010 0:00:00    160000      1000
# 4      Africa   East         Bill    10-01-2016 00:00    180000       123
# 5   Singapore   East       Thomas    08-07-2015 00:00    200000      1000
# 6     Mylasia   West         John   6/17/2013 0:00:00   1000000      7890
# 7       India   West         Bill  10/26/2012 0:00:00    240000       200
# 8          US   West       Thomas   6/26/2011 0:00:00  26000000      1000
# 9          UK  North         John   4/27/2013 0:00:00    100000      1000
# 10  Australia  North         Bill  11/25/2013 0:00:00    120000       567
# 11     Africa  North       Thomas    08-08-2017 00:00    140000      1000
# ...

# %%
PONumber=[100*i for i in range(21)]

# %%
print(PONumber)
# Out:
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000]

# %%
df["PONumber"]=PONumber

# %%
df
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity  \
# 0       India  North         John   3/17/2018 0:00:00    100000       567
# 1          US  North         Bill   1/21/2010 0:00:00    120000      3000
# 2          UK  North       Thomas   1/25/2015 0:00:00    140000       345
# 3   Australia   East         John   6/29/2010 0:00:00    160000      1000
# 4      Africa   East         Bill    10-01-2016 00:00    180000       123
# 5   Singapore   East       Thomas    08-07-2015 00:00    200000      1000
# 6     Mylasia   West         John   6/17/2013 0:00:00   1000000      7890
# 7       India   West         Bill  10/26/2012 0:00:00    240000       200
# 8          US   West       Thomas   6/26/2011 0:00:00  26000000      1000
# 9          UK  North         John   4/27/2013 0:00:00    100000      1000
# 10  Australia  North         Bill  11/25/2013 0:00:00    120000       567
# 11     Africa  North       Thomas    08-08-2017 00:00    140000      1000
# ...

# %%
df.set_index("PONumber",inplace=True)

# %%
df
# Out:
#             Country Region Sales Person    Date of Purchase     Total  \
# PONumber
# 0             India  North         John   3/17/2018 0:00:00    100000
# 100              US  North         Bill   1/21/2010 0:00:00    120000
# 200              UK  North       Thomas   1/25/2015 0:00:00    140000
# 300       Australia   East         John   6/29/2010 0:00:00    160000
# 400          Africa   East         Bill    10-01-2016 00:00    180000
# 500       Singapore   East       Thomas    08-07-2015 00:00    200000
# 600         Mylasia   West         John   6/17/2013 0:00:00   1000000
# 700           India   West         Bill  10/26/2012 0:00:00    240000
# 800              US   West       Thomas   6/26/2011 0:00:00  26000000
# 900              UK  North         John   4/27/2013 0:00:00    100000
# 1000      Australia  North         Bill  11/25/2013 0:00:00    120000
# 1100         Africa  North       Thomas    08-08-2017 00:00    140000
# ...

# %%
df.sort_index()
# Out:
#             Country Region Sales Person    Date of Purchase     Total  \
# PONumber
# 0             India  North         John   3/17/2018 0:00:00    100000
# 100              US  North         Bill   1/21/2010 0:00:00    120000
# 200              UK  North       Thomas   1/25/2015 0:00:00    140000
# 300       Australia   East         John   6/29/2010 0:00:00    160000
# 400          Africa   East         Bill    10-01-2016 00:00    180000
# 500       Singapore   East       Thomas    08-07-2015 00:00    200000
# 600         Mylasia   West         John   6/17/2013 0:00:00   1000000
# 700           India   West         Bill  10/26/2012 0:00:00    240000
# 800              US   West       Thomas   6/26/2011 0:00:00  26000000
# 900              UK  North         John   4/27/2013 0:00:00    100000
# 1000      Australia  North         Bill  11/25/2013 0:00:00    120000
# 1100         Africa  North       Thomas    08-08-2017 00:00    140000
# ...

# %%
df.sort_values(["Country","Region"], inplace=True)

# %%
df[["Country"]][df["Country"]=="Africa"]
# Out:
#          Country
# PONumber
# 400       Africa
# 1100      Africa
# 1800      Africa

# %%
df
# Out:
#             Country Region Sales Person    Date of Purchase     Total  \
# PONumber
# 400          Africa   East         Bill    10-01-2016 00:00    180000
# 1100         Africa  North       Thomas    08-08-2017 00:00    140000
# 1800         Africa  North         John   8/26/2015 0:00:00    140000
# 300       Australia   East         John   6/29/2010 0:00:00    160000
# 1000      Australia  North         Bill  11/25/2013 0:00:00    120000
# 1700      Australia   West       Thomas   3/29/2017 0:00:00    260000
# 1400          India   East       Thomas  12/19/2013 0:00:00    200000
# 0             India  North         John   3/17/2018 0:00:00    100000
# 700           India   West         Bill  10/26/2012 0:00:00    240000
# 1300        Mylasia   East         Bill   1/31/2014 0:00:00    180000
# 600         Mylasia   West         John   6/17/2013 0:00:00   1000000
# 500       Singapore   East       Thomas    08-07-2015 00:00    200000
# ...

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#             Country Region Sales Person    Date of Purchase     Total  \
# PONumber
# 0             India  North         John   3/17/2018 0:00:00    100000
# 100              US  North         Bill   1/21/2010 0:00:00    120000
# 200              UK  North       Thomas   1/25/2015 0:00:00    140000
# 300       Australia   East         John   6/29/2010 0:00:00    160000
# 400          Africa   East         Bill    10-01-2016 00:00    180000
# 500       Singapore   East       Thomas    08-07-2015 00:00    200000
# 600         Mylasia   West         John   6/17/2013 0:00:00   1000000
# 700           India   West         Bill  10/26/2012 0:00:00    240000
# 800              US   West       Thomas   6/26/2011 0:00:00  26000000
# 900              UK  North         John   4/27/2013 0:00:00    100000
# 1000      Australia  North         Bill  11/25/2013 0:00:00    120000
# 1100         Africa  North       Thomas    08-08-2017 00:00    140000
# ...

# %%
df.value_counts("Country")
# Out:
# Country
# Singapore    4
# Australia    3
# Africa       3
# India        3
# UK           3
# US           3
# Mylasia      2
# Name: count, dtype: int64

# %%
df[["Total", "Quantity"]].corr()
# Out:
#             Total  Quantity
# Total     1.00000  -0.08771
# Quantity -0.08771   1.00000

# %%
df[["Total", "Quantity"]] = df[["Total", "Quantity"]].astype(int)

# %%
df
# Out:
#             Country Region Sales Person    Date of Purchase     Total  \
# PONumber
# 0             India  North         John   3/17/2018 0:00:00    100000
# 100              US  North         Bill   1/21/2010 0:00:00    120000
# 200              UK  North       Thomas   1/25/2015 0:00:00    140000
# 300       Australia   East         John   6/29/2010 0:00:00    160000
# 400          Africa   East         Bill    10-01-2016 00:00    180000
# 500       Singapore   East       Thomas    08-07-2015 00:00    200000
# 600         Mylasia   West         John   6/17/2013 0:00:00   1000000
# 700           India   West         Bill  10/26/2012 0:00:00    240000
# 800              US   West       Thomas   6/26/2011 0:00:00  26000000
# 900              UK  North         John   4/27/2013 0:00:00    100000
# 1000      Australia  North         Bill  11/25/2013 0:00:00    120000
# 1100         Africa  North       Thomas    08-08-2017 00:00    140000
# ...

# %%
df.groupby(["Country", "Region"])["Total"].sum(numeric_only=True)
# Out:
# Country    Region
# Africa     East        180000
#            North       280000
# Australia  East        160000
#            North       120000
#            West        260000
# India      East        200000
#            North       100000
#            West        240000
# Mylasia    East        180000
#            West       1000000
# Singapore  East        360000
#            North     54484500
# UK         North       240000
#            West        240000
# US         North       120000
#            West      26220000
# Name: Total, dtype: int64

# %%
df["Date of Purchase"] = pd.to_datetime(df["Date of Purchase"], format='mixed', dayfirst=True)

# %%
df
# Out:
#             Country Region Sales Person Date of Purchase     Total  Quantity  \
# PONumber
# 0             India  North         John       2018-03-17    100000       567
# 100              US  North         Bill       2010-01-21    120000      3000
# 200              UK  North       Thomas       2015-01-25    140000       345
# 300       Australia   East         John       2010-06-29    160000      1000
# 400          Africa   East         Bill       2016-01-10    180000       123
# 500       Singapore   East       Thomas       2015-07-08    200000      1000
# 600         Mylasia   West         John       2013-06-17   1000000      7890
# 700           India   West         Bill       2012-10-26    240000       200
# 800              US   West       Thomas       2011-06-26  26000000      1000
# 900              UK  North         John       2013-04-27    100000      1000
# 1000      Australia  North         Bill       2013-11-25    120000       567
# ...

# %%
df.groupby(df["Date of Purchase"].dt.year)["Quantity"].sum(numeric_only=True)
# Out:
# Date of Purchase
# 2010    4892
# 2011    1090
# 2012     200
# 2013    9547
# 2014     614
# 2015    1430
# 2016     123
# 2017    1090
# 2018     657
# Name: Quantity, dtype: int64

# %%
df.groupby(df["Date of Purchase"].dt.year)["Quantity"].sum(numeric_only=True)
# Out:
# Date of Purchase
# 2010    4892
# 2011    1090
# 2012     200
# 2013    9547
# 2014     614
# 2015    1430
# 2016     123
# 2017    1090
# 2018     657
# Name: Quantity, dtype: int64

# %%
df
# Out:
#             Country Region Sales Person Date of Purchase     Total  Quantity  \
# PONumber
# 0             India  North         John       2018-03-17    100000       567
# 100              US  North         Bill       2010-01-21    120000      3000
# 200              UK  North       Thomas       2015-01-25    140000       345
# 300       Australia   East         John       2010-06-29    160000      1000
# 400          Africa   East         Bill       2016-01-10    180000       123
# 500       Singapore   East       Thomas       2015-07-08    200000      1000
# 600         Mylasia   West         John       2013-06-17   1000000      7890
# 700           India   West         Bill       2012-10-26    240000       200
# 800              US   West       Thomas       2011-06-26  26000000      1000
# 900              UK  North         John       2013-04-27    100000      1000
# 1000      Australia  North         Bill       2013-11-25    120000       567
# ...

# %%
df["Yeaar"] = df["Date of Purchase"].dt.year

# %%
df.groupby(["Country" , "Yeaar"])["Total"].sum()
# Out:
# Country    Yeaar
# Africa     2015       140000
#            2016       180000
#            2017       140000
# Australia  2010       160000
#            2013       120000
#            2017       260000
# India      2012       240000
#            2013       200000
#            2018       100000
# Mylasia    2013      1000000
#            2014       180000
# Singapore  2010       160000
#            2014     54484500
#            2015       200000
# UK         2011       240000
#            2013       100000
#            2015       140000
# US         2010       120000
#            2011     26000000
#            2018       220000
# Name: Total, dtype: int64

# %%
df.groupby(["Country" , "Yeaar"])["Quantity"].agg(["sum", "min", "max"])
# Out:
#                   sum   min   max
# Country   Yeaar
# Africa    2015     85    85    85
#           2016    123   123   123
#           2017   1000  1000  1000
# Australia 2010   1000  1000  1000
#           2013    567   567   567
#           2017     90    90    90
# India     2012    200   200   200
#           2013     90    90    90
#           2018    567   567   567
# Mylasia   2013   7890  7890  7890
#           2014    444   444   444
# Singapore 2010    892   892   892
#           2014    170    85    85
#           2015   1000  1000  1000
# UK        2011     90    90    90
#           2013   1000  1000  1000
#           2015    345   345   345
# US        2010   3000  3000  3000
#           2011   1000  1000  1000
#           2018     90    90    90

# %%
visual = df.groupby("Country")["Total"].agg("sum")

# %%
visual
# Out:
# Country
# Africa         460000
# Australia      540000
# India          540000
# Mylasia       1180000
# Singapore    54844500
# UK             480000
# US           26340000
# Name: Total, dtype: int64

# %%
visual.to_string()
# Out:
# 'Country\nAfrica         460000\nAustralia      540000\nIndia          540000\nMylasia       1180000\nSingapore    54844500\nUK             480000\nUS           26340000'

# %%
import matplotlib.pyplot as plt

# %%
visual.plot.pie()
# Out:
# <Axes: ylabel='Total'>

# %%
import seaborn as sns

# %% [markdown]
# df

# %%
df
# Out:
#             Country Region Sales Person Date of Purchase     Total  Quantity  \
# PONumber
# 0             India  North         John       2018-03-17    100000       567
# 100              US  North         Bill       2010-01-21    120000      3000
# 200              UK  North       Thomas       2015-01-25    140000       345
# 300       Australia   East         John       2010-06-29    160000      1000
# 400          Africa   East         Bill       2016-01-10    180000       123
# 500       Singapore   East       Thomas       2015-07-08    200000      1000
# 600         Mylasia   West         John       2013-06-17   1000000      7890
# 700           India   West         Bill       2012-10-26    240000       200
# 800              US   West       Thomas       2011-06-26  26000000      1000
# 900              UK  North         John       2013-04-27    100000      1000
# 1000      Australia  North         Bill       2013-11-25    120000       567
# ...

# %%
corr = df[["Total", "Quantity", "temp_dta", "Yeaar"]].corr()

# %%
sns.heatmap( corr, annot=True)
# Out:
# <Axes: >

# %%
new_df = pd.DataFrame()

# %%
new_df["Employee"] = df["Sales Person"].unique()

# %%
import random

# %%
a=[2,4,5,3]
random.shuffle(a)

# %%
new_df
# Out:
#   Employee
# 0     John
# 1     Bill
# 2   Thomas
# 3   Rubesh

# %%
new_df["Company experience"] = a

# %%
new_df["Total Exprience"] = new_df["Company experience"] + random.randint(1,10)

# %%
new_df
# Out:
#   Employee  Company experience  Total Exprience
# 0     John                   5               12
# 1     Bill                   4               11
# 2   Thomas                   2                9
# 3   Rubesh                   3               10

# %%
df.merge(new_df, left_on="Sales Person", right_on="Employee")
# Out:
#       Country Region Sales Person Date of Purchase     Total  Quantity  \
# 0       India  North         John       2018-03-17    100000       567
# 1          US  North         Bill       2010-01-21    120000      3000
# 2          UK  North       Thomas       2015-01-25    140000       345
# 3   Australia   East         John       2010-06-29    160000      1000
# 4      Africa   East         Bill       2016-01-10    180000       123
# 5   Singapore   East       Thomas       2015-07-08    200000      1000
# 6     Mylasia   West         John       2013-06-17   1000000      7890
# 7       India   West         Bill       2012-10-26    240000       200
# 8          US   West       Thomas       2011-06-26  26000000      1000
# 9          UK  North         John       2013-04-27    100000      1000
# 10  Australia  North         Bill       2013-11-25    120000       567
# 11     Africa  North       Thomas       2017-08-08    140000      1000
# ...

# %%
print(df['Sales Person'].dtype)
print(new_df['Employee'].dtype)
# Out:
# object
# object

# %%
df['Sales Person'] = df['Sales Person'].astype(str)
new_df['Employee'] = new_df['Employee'].astype(str)

# %%
df['Sales Person'] = df['Sales Person'].str.strip()
new_df['Employee'] = new_df['Employee'].str.strip()

# %%
print(df['Sales Person'].dtype)
print(new_df['Employee'].dtype)
# Out:
# object
# object

# %%
result = df.merge(new_df, left_on="Sales Person", right_on="Employee", how="outer", indicator=True)
print(result['_merge'].value_counts())
# Out:
# _merge
# both          21
# left_only      0
# right_only     0
# Name: count, dtype: int64

# %%
print(df['Sales Person'].duplicated().sum())
print(new_df['Employee'].duplicated().sum())
# Out:
# 17
# 0

# %%
df.set_index("Sales Person", inplace=True)

# %%
new_df.set_index("Employee", inplace = True)

# %%
new_df
# Out:
#           Company experience  Total Exprience
# Employee
# John                       5               12
# Bill                       4               11
# Thomas                     2                9
# Rubesh                     3               10

# %%
df.join(new_df)
# Out:
#                 Country Region Date of Purchase     Total  Quantity temp_dta  \
# Sales Person
# John              India  North       2018-03-17    100000       567        0
# Bill                 US  North       2010-01-21    120000      3000        1
# Thomas               UK  North       2015-01-25    140000       345        4
# John          Australia   East       2010-06-29    160000      1000        9
# Bill             Africa   East       2016-01-10    180000       123       16
# Thomas        Singapore   East       2015-07-08    200000      1000       25
# John            Mylasia   West       2013-06-17   1000000      7890       36
# Bill              India   West       2012-10-26    240000       200       49
# Thomas               US   West       2011-06-26  26000000      1000       64
# John                 UK  North       2013-04-27    100000      1000       81
# Bill          Australia  North       2013-11-25    120000       567      100
# ...
