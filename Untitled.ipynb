# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Create random data
np.random.seed(42)
x = np.random.normal(size=1000)
y = 2 * x + np.random.normal(size=1000)

# Create a bivariate KDE plot
sns.kdeplot(x=x, y=y, cmap="Blues", fill=True)

# Add labels and title
plt.title("Bivariate KDE Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Create random data
np.random.seed(42)
x = np.random.normal(size=1000)
y = 2 * x + np.random.normal(size=1000)

# Create a bivariate KDE plot
sns.kdeplot(x=x, y=y, cmap="Blues", fill=True)

# Add labels and title
plt.title("Bivariate KDE Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

sns.scatterplot(x=x, y=y)
plt.title("Scatter Plot")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Create random data
np.random.seed(42)
x = np.random.normal(size=1000)
y = 2 * x + np.random.normal(size=1000)

# Create a bivariate KDE plot
sns.kdeplot(x=x, y=y, cmap="Blues", fill=True)

# Add labels and title
plt.title("Bivariate KDE Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

sns.histplot(x=x, y=y, bins=30, pmax=0.8, cmap="mako")
plt.title("Hexbin Plot")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Create random data
np.random.seed(42)
x = np.random.normal(size=1000)
y = 2 * x + np.random.normal(size=1000)

# Create a bivariate KDE plot
sns.kdeplot(x=x, y=y, cmap="Blues", fill=True)

# Add labels and title
plt.title("Bivariate KDE Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

sns.pairplot(data=sns.load_dataset("iris"), hue="species")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('C:/Users/Rubesh/Documents/GitHub/My_studies/sales_data.csv')

# Display the first few rows of the dataset
print(df.head())

# Set a consistent style for Seaborn plots
sns.set_theme(style="whitegrid")

# 1. Relationship Between Marketing Spend and Sales
sns.lmplot(data=df, x="Marketing_Spend", y="Sales", height=6, aspect=1.5)
plt.title("Relationship Between Marketing Spend and Sales")
plt.show()

# 2. Compare Sales Across Regions
sns.boxplot(data=df, x="Region", y="Sales", palette="Set2")
plt.title("Sales Distribution by Region")
plt.show()

# 3. Analyze Profit Margins by Product Category
sns.barplot(data=df, x="Product_Category", y="Profit", ci=None, palette="mako")
plt.title("Average Profit by Product Category")
plt.show()

# 4. Correlation Heatmap
corr = df[["Sales", "Profit", "Marketing_Spend"]].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", square=True)
plt.title("Correlation Heatmap")
plt.show()

# 5. Sales Trends Across Product Categories and Regions
sns.catplot(data=df, x="Product_Category", y="Sales", hue="Region", kind="bar", height=6, aspect=2, palette="pastel")
plt.title("Sales by Product Category and Region")
plt.show()

# 6. Analyze Profit and Sales Distribution
sns.jointplot(data=df, x="Sales", y="Profit", kind="kde", fill=True, cmap="crest")
plt.suptitle("Joint Distribution of Sales and Profit", y=1.02)
plt.show()
# Out:
#   Region    Sales   Profit  Marketing_Spend Product_Category
# 0   East  3650.04   761.11          2491.34        Furniture
# 1   West  4465.88  4711.19          1703.81      Electronics
# 2  North  8660.23  3213.00           793.27      Electronics
# 3   East  3852.30  1807.55           812.96      Electronics
# 4   East  2525.43   868.51          2213.91      Electronics
# C:\Users\Rubesh\AppData\Local\Temp\ipykernel_10404\1100018048.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Region", y="Sales", palette="Set2")
# C:\Users\Rubesh\AppData\Local\Temp\ipykernel_10404\1100018048.py:25: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Product_Category", y="Profit", ci=None, palette="mako")
# ...
